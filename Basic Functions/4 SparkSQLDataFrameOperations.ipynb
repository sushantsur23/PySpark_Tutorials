# %%
# %sh
wget https://mas-dse-open.s3.amazonaws.com/Weather/by_state/NY.tgz
tar zxvf NY.tgz
#ls -ltr /databricks/driver/NY.parquet/
cp /databricks/driver/NY.parquet/* /dbfs/tmp/NYPARQ/
ls -ltr /dbfs/tmp/NYPARQ/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2021-09-05 04:29:26--  https://mas-dse-open.s3.amazonaws.com/Weather/by_state/NY.tgz
# Resolving mas-dse-open.s3.amazonaws.com (mas-dse-open.s3.amazonaws.com)... 52.92.164.193
# Connecting to mas-dse-open.s3.amazonaws.com (mas-dse-open.s3.amazonaws.com)|52.92.164.193|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2021-09-05 04:29:26 ERROR 404: Not Found.
#
# tar (child): NY.tgz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# cp: cannot stat &#39;/databricks/driver/NY.parquet/*&#39;: No such file or directory
# total 0
# -rw-r--r-- 1 root root 4138689 Jun 20  2020 part-00001-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3660544 Jun 20  2020 part-00000-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3946287 Jun 20  2020 part-00002-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 4004047 Jun 20  2020 part-00003-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2836314 Jun 20  2020 part-00005-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3949516 Jun 20  2020 part-00004-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3317024 Jun 20  2020 part-00006-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2616239 Jun 20  2020 part-00008-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3929807 Jun 20  2020 part-00007-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3865388 Jun 20  2020 part-00009-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3655620 Jun 20  2020 part-00011-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3333004 Jun 20  2020 part-00010-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3532197 Jun 20  2020 part-00012-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 1431820 Jun 20  2020 part-00014-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3913946 Jun 20  2020 part-00013-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2088969 Jun 20  2020 part-00015-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2340575 Jun 20  2020 part-00017-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 1737280 Jun 20  2020 part-00016-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2007068 Jun 20  2020 part-00018-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 1600288 Jun 20  2020 part-00019-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3170504 Jun 20  2020 part-00020-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 1766711 Jun 20  2020 part-00022-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2507358 Jun 20  2020 part-00021-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2094306 Jun 20  2020 part-00023-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 1421413 Jun 20  2020 part-00025-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 2705496 Jun 20  2020 part-00024-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root  103149 Jun 20  2020 part-00027-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root 3951224 Jun 20  2020 part-00026-89caf7c0-9733-40ec-a650-7f368529dd01-c000.snappy.parquet
# -rw-r--r-- 1 root root       0 Jun 20  2020 _SUCCESS
# </div>

# %%
from pyspark.sql.types import Row, StructField, StructType, StringType, IntegerType

df = spark.read.parquet("/tmp/NYPARQ/")
df.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
#     Station|Measurement|Year|              Values|       dist_coast|      latitude|         longitude|        elevation|state|             name|
# +-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
# USW00094704|   PRCP_s20|1945|[00 00 00 00 00 0...|361.8320007324219|42.57080078125|-77.71330261230469|208.8000030517578|   NY|DANSVILLE MUNI AP|
# +-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
# only showing top 1 row
#
# </div>

# %% [markdown]
# ## Dataframe operations
# Spark DataFrames allow operations similar to pandas Dataframes. We demonstrate some of those.
#
# For more, see the [official guide](https://spark.apache.org/docs/latest/sql-programming-guide.html) and [this article](https://www.analyticsvidhya.com/blog/2016/10/spark-dataframe-and-operations/)

# %%
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Station: string (nullable = true)
# -- Measurement: string (nullable = true)
# -- Year: long (nullable = true)
# -- Values: binary (nullable = true)
# -- dist_coast: double (nullable = true)
# -- latitude: double (nullable = true)
# -- longitude: double (nullable = true)
# -- elevation: double (nullable = true)
# -- state: string (nullable = true)
# -- name: string (nullable = true)
#
# </div>

# %%
print(df.count())
df.show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">168398
# +-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
#     Station|Measurement|Year|              Values|       dist_coast|      latitude|         longitude|        elevation|state|             name|
# +-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
# USW00094704|   PRCP_s20|1945|[00 00 00 00 00 0...|361.8320007324219|42.57080078125|-77.71330261230469|208.8000030517578|   NY|DANSVILLE MUNI AP|
# +-----------+-----------+----+--------------------+-----------------+--------------+------------------+-----------------+-----+-----------------+
# only showing top 1 row
#
# </div>

# %% [markdown]
# ### .describe()
# The method `df.describe()` computes five statistics for each column of the dataframe `df`.
#
# The statistics are: **count, mean, std, min,max**

# %% [markdown]
# You get the following man page using the command `df.describe?`
#
# ```
# Signature: df.describe(*cols)
# Docstring:
# Computes statistics for numeric and string columns.
#
# This include count, mean, stddev, min, and max. If no columns are
# given, this function computes statistics for all numerical or string columns.
#
# .. note:: This function is meant for exploratory data analysis, as we make no
#     guarantee about the backward compatibility of the schema of the resulting DataFrame.
#
# >>> df.describe(['age']).show()
# +-------+------------------+
# |summary|               age|
# +-------+------------------+
# |  count|                 2|
# |   mean|               3.5|
# | stddev|2.1213203435596424|
# |    min|                 2|
# |    max|                 5|
# +-------+------------------+
# >>> df.describe().show()
# +-------+------------------+-----+
# |summary|               age| name|
# +-------+------------------+-----+
# |  count|                 2|    2|
# |   mean|               3.5| null|
# | stddev|2.1213203435596424| null|
# |    min|                 2|Alice|
# |    max|                 5|  Bob|
# +-------+------------------+-----+
#
# .. versionadded:: 1.3.1
# File:      ~/spark-2.2.1-bin-hadoop2.7/python/pyspark/sql/dataframe.py
# Type:      method
# ```

# %%
df.describe().select('station','measurement').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+
#     station|measurement|
# +-----------+-----------+
#      168398|     168398|
#        null|       null|
#        null|       null|
# USC00300015|       PRCP|
# USW00094794|   TOBS_s20|
# +-----------+-----------+
#
# </div>

# %% [markdown]
# #### groupby and agg
# The method `.groupby(col)` groups rows according the value of the column `col`.
# The method `.agg(spec)` computes a summary for each group as specified in `spec`

# %%
df.groupby('measurement').agg({'year': 'min', 'station':'count'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+---------+--------------+
# measurement|min(year)|count(station)|
# +-----------+---------+--------------+
#    TMIN_s20|     1873|         13442|
#        TMIN|     1873|         13442|
#    SNOW_s20|     1884|         15629|
#        TOBS|     1876|         10956|
#    SNWD_s20|     1888|         14617|
#    PRCP_s20|     1871|         16118|
#    TOBS_s20|     1876|         10956|
#        TMAX|     1873|         13437|
#        SNOW|     1884|         15629|
#    TMAX_s20|     1873|         13437|
#        SNWD|     1888|         14617|
#        PRCP|     1871|         16118|
# +-----------+---------+--------------+
#
# </div>

# %%
# THis command will load the python module that defines the SQL functions
#%load ls ~/spark-latest/python/pyspark/sql/functions.py

# %% [markdown]
# ### Using SQL queries on DataFrames
#
# There are two main ways to manipulate  DataFrames:

# %% [markdown]
# #### Imperative manipulation
# Using python methods such as `.select` and `.groupby`.
# * Advantage: order of operations is specified.
# * Disrdavantage : You need to describe both **what** is the result you want and **how** to get it.

# %% [markdown]
# #### Declarative Manipulation (SQL)
# * Advantage: You need to describe only **what** is the result you want.
# * Disadvantage: SQL does not have primitives for common analysis operations such as **covariance**

# %% [markdown]
# ### Using sql commands on a dataframe
# Spark supports a [subset](https://spark.apache.org/docs/latest/sql-programming-guide.html#supported-hive-features) of the Hive SQL query language.
#
# For example, You can use [Hive `select` syntax](https://cwiki.apache.org/confluence/display/Hive/LanguageManual+Select) to select a subset of the rows in a dataframe.
#
# To use sql on a dataframe you need to first `register` it as a `TempTable`.
#
# for variety, we are using here a small dataframe loaded from a JSON file.

# %%
# when loading json files you can specify either a single file or a directory containing many json files.
path = "/FileStore/tables/people.json"

# Create a DataFrame from the file(s) pointed to by path
people = spark.read.json(path)
#print('people is a',type(people))
# The inferred schema can be visualized using the printSchema() method.
people.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
#  age|   name|
# +----+-------+
# null|Michael|
#   30|   Andy|
#   19| Justin|
# +----+-------+
#
# </div>

# %%
people.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- age: long (nullable = true)
# -- name: string (nullable = true)
#
# </div>

# %%
# Register this DataFrame as a table.
people.registerTempTable("people")

# SQL statements can be run by using the sql methods provided by sqlContext
teenagers = sql("SELECT name FROM people WHERE age >= 13 AND age <= 19")
teenagers.show()
teenagers.write.save("teenagersdataneew")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+
#   name|
# +------+
# Justin|
# +------+
#
# </div>

# %%
# %sh

ls -ltr /dbfs/teenagersdata/
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 0
# -rw-r--r-- 1 root root   0 Jun 21 06:12 _started_3226332471664364021
# -rw-r--r-- 1 root root 445 Jun 21 06:12 part-00000-tid-3226332471664364021-bd85ae5c-239c-454b-862e-d6aa5d2b7e20-387-1-c000.snappy.parquet
# -rw-r--r-- 1 root root   0 Jun 21 06:12 _SUCCESS
# -rw-r--r-- 1 root root 124 Jun 21 06:12 _committed_3226332471664364021
# </div>

# %% [markdown]
# #### Counting the number of occurances of each measurement, imparatively

# %%
L=df.groupBy('measurement').count().collect()
#L is a list (collected DataFrame)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
D=[(e.measurement,e['count']) for e in L]
sorted(D,key=lambda x:x[1], reverse=False)[:6]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: [(&#39;TOBS&#39;, 10956),
#  (&#39;TOBS_s20&#39;, 10956),
#  (&#39;TMAX&#39;, 13437),
#  (&#39;TMAX_s20&#39;, 13437),
#  (&#39;TMIN_s20&#39;, 13442),
#  (&#39;TMIN&#39;, 13442)]</div>

# %% [markdown]
# #### Counting the number of occurances of each measurement, declaratively.

# %%
df.registerTempTable('weather')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
query="""
SELECT measurement,COUNT(measurement) AS count,
                   MIN(year) AS MinYear 
FROM weather  
GROUP BY measurement 
ORDER BY count
"""
print(query)

sql(query).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">
# SELECT measurement,COUNT(measurement) AS count,
#                    MIN(year) AS MinYear
# FROM weather
# GROUP BY measurement
# ORDER BY count
#
# +-----------+-----+-------+
# measurement|count|MinYear|
# +-----------+-----+-------+
#    TOBS_s20|10956|   1876|
#        TOBS|10956|   1876|
#        TMAX|13437|   1873|
#    TMAX_s20|13437|   1873|
#        TMIN|13442|   1873|
#    TMIN_s20|13442|   1873|
#    SNWD_s20|14617|   1888|
#        SNWD|14617|   1888|
#        SNOW|15629|   1884|
#    SNOW_s20|15629|   1884|
#    PRCP_s20|16118|   1871|
#        PRCP|16118|   1871|
# +-----------+-----+-------+
#
# </div>

# %% [markdown]
# #### Performing a map command
# * In order to perform a `map` on a dataframe, you first need to transform it into an RDD.

# %% [markdown]
# * **Not** the recommended way. Better way is to use built-in sparkSQL functions.
# * Or register new ones (Advanced).

# %%
def find_century(row):
    if row.Year < 1900:
        return '19th'
    elif row.Year <2000:
        return '20th'
    elif row.Year <2010:
        return '21st'
    else:
        return 'possibly_bad_data'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.rdd.map(find_century).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: [&#39;20th&#39;, &#39;20th&#39;, &#39;20th&#39;, &#39;20th&#39;, &#39;20th&#39;]</div>

# %% [markdown]
# #### Aggregations
# * **Aggregation** can be used, in combination with built-in sparkSQL functions
# to compute statistics of a dataframe.
# * computation will be fast thanks to combined optimzations with database operations.

# %% [markdown]
# * A partial list : `count(), approx_count_distinct(), avg(), max(), min()`

# %% [markdown]
# * Of these, the interesting one is `approx_count_distinct()` which uses sampling to get an approximate count fast.

# %% [markdown]
# * [The gory details](http://spark.apache.org/docs/2.2.0/api/python/_modules/pyspark/sql/functions.html)

# %%
import pyspark.sql.functions as F # used here just for show.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.agg({'station':'approx_count_distinct'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------------------+
# approx_count_distinct(station)|
# +------------------------------+
#                            339|
# +------------------------------+
#
# </div>

# %% [markdown]
# #### Approximate Quantile
#
# * Suppose we want to partition the years into 10 ranges
# * such that in each range we have approximately the same number of records.
# * The method `.approxQuantile` will use a sample to do this for us.

# %%
print('with accuracy 0.1: ',df.approxQuantile('year', [0.1*i for i in range(1,10)], 0.1))
print('with accuracy 0.01: ',df.approxQuantile('year', [0.1*i for i in range(1,10)], 0.01))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">with accuracy 0.1:  [1871.0, 1928.0, 1948.0, 1957.0, 1965.0, 1974.0, 1984.0, 1994.0, 2013.0]
# with accuracy 0.01:  [1920.0, 1938.0, 1949.0, 1957.0, 1965.0, 1975.0, 1984.0, 1993.0, 2003.0]
# </div>

# %% [markdown]
# #### Lets collect the exact number of rows for each year
# This will take much longer than ApproxQuantile on a large file

# %%
# Lets collect the exact number of rows for each year ()
query='SELECT year,COUNT(year) AS count FROM weather GROUP BY year ORDER BY year'
print(query)
counts=sqlContext.sql(query)
print('counts is ',counts)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">SELECT year,COUNT(year) AS count FROM weather GROUP BY year ORDER BY year
# counts is  DataFrame[year: bigint, count: bigint]
# </div>

# %%
import pandas as pd    
A=counts.toPandas() # Transform a spark Dataframe to a Pandas Dataframe
A.plot.line('year','count')
grid()

# %% [markdown]
# ## Summary
#
# * Dataframes can be manipulated decleratively, which allows for more optimization.
# * Dataframes can be stored and retrieved from Parquet files.
# * It is possible to refer directly to a parquet file in an SQL query.
# * See you next time!

# %% [markdown]
# ## References
# * For an introduction to Spark SQL and Dataframes see: [Spark SQL, DataFrames](https://spark.apache.org/docs/latest/sql-programming-guide.html#spark-sql-dataframes-and-datasets-guide)
# * Also [spark-dataframe-and-operations](https://www.analyticsvidhya.com/blog/2016/10/spark-dataframe-and-operations/) from [analyticsvidhya.com](https://www.analyticsvidhya.com)
#
# For complete API reference see
# * [SQL programming guide](https://spark.apache.org/docs/latest/sql-programming-guide.html) For Java, Scala and Python (Implementation is first in Scala and Python, later pyspark)
# * [pyspark API for the DataFrame class](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.DataFrame)
# * [pyspark API for the pyspark.sql module](http://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark-sql-module)
